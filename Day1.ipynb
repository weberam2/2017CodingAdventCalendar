# %%
import pandas
import numpy as np

# %%
inpt = ...

# %%
intlength = len(str(inpt))

# %%
intlength
# Out:
# 2124

# %%
inpt[-1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-43d7474a1dfa> in <module>()
# ----> 1 inpt[-1]
#
# TypeError: 'int' object is not subscriptable

# %%
list(str(inpt))
# Out:
# ['4',
#  '9',
#  '4',
#  '7',
#  '5',
#  '1',
#  '1',
#  '3',
#  '6',
#  '8',
#  '9',
#  '5',
#  '3',
#  '4',
#  '5',
#  '8',
#  '9',
#  '4',
#  '7',
#  '3',
#  '2',
#  '5',
#  '8',
#  '2',
#  '3',
#  '6',
#  '2',
#  '6',
#  '2',
#  '9',
#  '5',
#  '7',
#  '6',
#  '5',
#  '3',
#  '9',
#  '5',
#  '9',
#  '9',
#  '1',
#  '8',
#  '4',
#  '2',
#  '9',
#  '6',
#  '1',
#  '9',
#  '5',
#  '3',
#  '1',
#  '8',
#  '1',
#  '6',
#  '2',
#  '6',
#  '6',
#  '4',
#  '6',
#  '9',
#  '5',
#  '1',
#  '8',
#  '9',
#  '3',
#  '9',
#  '3',
#  '3',
#  '6',
#  '4',
#  '3',
#  '7',
#  '2',
#  '5',
#  '8',
#  '5',
#  '7',
#  '7',
#  '8',
#  '8',
#  '6',
#  '8',
#  '5',
#  '1',
#  '2',
#  '1',
#  '9',
#  '4',
#  '8',
#  '6',
#  '3',
#  '9',
#  '2',
#  '7',
#  '6',
#  '5',
#  '2',
#  '7',
#  '8',
#  '8',
#  '1',
#  '4',
#  '9',
#  '7',
#  '7',
#  '9',
#  '7',
#  '4',
#  '8',
#  '6',
#  '5',
#  '7',
#  '9',
#  '8',
#  '9',
#  '3',
#  '1',
#  '8',
#  '6',
#  '4',
#  '5',
#  '9',
#  '3',
#  '6',
#  '2',
#  '2',
# ...

# %%
inptlist = list(str(inpt))

# %%
inptlist[-1]
# Out:
# '4'
