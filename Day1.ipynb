# %%
import pandas
import numpy as np

# %%
inpt = ...

# %%
intlength = len(str(inpt))

# %%
intlength
# Out:
# 2124

# %%
list(str(inpt))
# Out:
# ['4',
#  '9',
#  '4',
#  '7',
#  '5',
#  '1',
#  '1',
#  '3',
#  '6',
#  '8',
#  '9',
#  '5',
#  '3',
#  '4',
#  '5',
#  '8',
#  '9',
#  '4',
#  '7',
#  '3',
#  '2',
#  '5',
#  '8',
#  '2',
#  '3',
#  '6',
#  '2',
#  '6',
#  '2',
#  '9',
#  '5',
#  '7',
#  '6',
#  '5',
#  '3',
#  '9',
#  '5',
#  '9',
#  '9',
#  '1',
#  '8',
#  '4',
#  '2',
#  '9',
#  '6',
#  '1',
#  '9',
#  '5',
#  '3',
#  '1',
#  '8',
#  '1',
#  '6',
#  '2',
#  '6',
#  '6',
#  '4',
#  '6',
#  '9',
#  '5',
#  '1',
#  '8',
#  '9',
#  '3',
#  '9',
#  '3',
#  '3',
#  '6',
#  '4',
#  '3',
#  '7',
#  '2',
#  '5',
#  '8',
#  '5',
#  '7',
#  '7',
#  '8',
#  '8',
#  '6',
#  '8',
#  '5',
#  '1',
#  '2',
#  '1',
#  '9',
#  '4',
#  '8',
#  '6',
#  '3',
#  '9',
#  '2',
#  '7',
#  '6',
#  '5',
#  '2',
#  '7',
#  '8',
#  '8',
#  '1',
#  '4',
#  '9',
#  '7',
#  '7',
#  '9',
#  '7',
#  '4',
#  '8',
#  '6',
#  '5',
#  '7',
#  '9',
#  '8',
#  '9',
#  '3',
#  '1',
#  '8',
#  '6',
#  '4',
#  '5',
#  '9',
#  '3',
#  '6',
#  '2',
#  '2',
# ...

# %%
inptlist = list(str(inpt))

# %%
inptlist[-1]
# Out:
# '4'

# %%
inptlist[1] == inptlist[2]
# Out:
# False

# %%
captcha = 0
for i in range(len(inptlist)):
    if i == len(inptlist)-1:
        print(i,0,inptlist[i],inptlist[-1],inptlist[i]==inptlist[-1])
        if inptlist[i]==inptlist[-1]:
            captcha = captcha + int(inptlist[i])
    else:
        print(i,i+1,inptlist[i],inptlist[i+1],inptlist[i]==inptlist[i+1])
        if inptlist[i]==inptlist[i+1]:
            captcha = captcha + int(inptlist[i])
        
print()
print("Captcha equals", captcha)
# Out:
# 0 1 4 9 False
# 1 2 9 4 False
# 2 3 4 7 False
# 3 4 7 5 False
# 4 5 5 1 False
# 5 6 1 1 True
# 6 7 1 3 False
# 7 8 3 6 False
# 8 9 6 8 False
# 9 10 8 9 False
# 10 11 9 5 False
# 11 12 5 3 False
# 12 13 3 4 False
# 13 14 4 5 False
# 14 15 5 8 False
# 15 16 8 9 False
# 16 17 9 4 False
# 17 18 4 7 False
# 18 19 7 3 False
# 19 20 3 2 False
# 20 21 2 5 False
# 21 22 5 8 False
# 22 23 8 2 False
# 23 24 2 3 False
# 24 25 3 6 False
# 25 26 6 2 False
# 26 27 2 6 False
# 27 28 6 2 False
# 28 29 2 9 False
# 29 30 9 5 False
# 30 31 5 7 False
# 31 32 7 6 False
# 32 33 6 5 False
# 33 34 5 3 False
# 34 35 3 9 False
# 35 36 9 5 False
# 36 37 5 9 False
# 37 38 9 9 True
# 38 39 9 1 False
# 39 40 1 8 False
# 40 41 8 4 False
# 41 42 4 2 False
# 42 43 2 9 False
# 43 44 9 6 False
# 44 45 6 1 False
# 45 46 1 9 False
# 46 47 9 5 False
# 47 48 5 3 False
# 48 49 3 1 False
# 49 50 1 8 False
# 50 51 8 1 False
# 51 52 1 6 False
# 52 53 6 2 False
# 53 54 2 6 False
# 54 55 6 6 True
# 55 56 6 4 False
# ...
